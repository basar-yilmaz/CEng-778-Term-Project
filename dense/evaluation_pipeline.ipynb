# %%
import pickle

# Load document embeddings
with open("doc_embeddings.pkl", "rb") as f:
    doc_data = pickle.load(f)
doc_embeddings = doc_data["embeddings"]
doc_ids = doc_data["doc_ids"]

# Load query embeddings
with open("query_embeddings.pkl", "rb") as f:
    query_data = pickle.load(f)
query_embeddings = query_data["embeddings"]
query_ids = query_data["query_ids"]

print("Document Embeddings Shape:", doc_embeddings.shape)
print("Query Embeddings Shape:", query_embeddings.shape)

# Load queries
with open("../data/queries.pkl", "rb") as f:
    queries = pickle.load(f)

print("Number of Queries:", len(queries))
# Out:
# Document Embeddings Shape: (210157, 768)
# Query Embeddings Shape: (150, 768)
# Number of Queries: 150

# %%
# preprocess queries
queries_filtered = [query for query in queries if query.number_of_relevant_docs > 0]

print("Number of Queries with Relevant Documents:", len(queries_filtered))
# Out:
# Number of Queries with Relevant Documents: 143

# %%
import faiss

embedding_dim = doc_embeddings.shape[1]
index = faiss.IndexFlatIP(embedding_dim)

faiss.normalize_L2(doc_embeddings)  # normalize before adding to index
faiss.normalize_L2(query_embeddings)  # normalize before searching

index.add(doc_embeddings)

print(f"FAISS index contains {index.ntotal} embeddings.")
# Out:
# FAISS index contains 210157 embeddings.

# %%
# Number of nearest neighbors to retrieve
top_k = 1000

# Search the index with normalized query embeddings
distances, indices = index.search(query_embeddings, top_k)

print("Distances Shape:", distances.shape)  # (num_queries, top_k)
print("Indices Shape:", indices.shape)  # (num_queries, top_k)
# Out:
# Distances Shape: (150, 1000)
# Indices Shape: (150, 1000)

# %%
# Map indices to document IDs and reverse the order by similarity
results_map = [
    {
        "query_id": query_ids[i],
        "top_docs": sorted(
            [
                {"doc_id": doc_ids[idx], "similarity": distances[i][j]}
                for j, idx in enumerate(indices[i])
            ],
            key=lambda x: x["similarity"],
            reverse=True,
        ),
    }
    for i in range(len(query_ids))
]

# # Print results for each query
# for result in results:
#     print(f"Query ID: {result['query_id']}")
#     for doc in result["top_docs"]:
#         print(f"  Doc ID: {doc['doc_id']}\t Similarity: {doc['similarity']:.6f}")

# %%
# Evaluation
import pytrec_eval

# Create qrels from queries
qrels = {
    query.query_no: {
        doc_id: 1 for doc_id in query.relevant_docs
    }  # Relevance score = 1 for relevant documents
    for query in queries_filtered
}


# print(qrels)

# %%
run = {
    query_ids[i]: {
        doc_ids[idx]: float(distances[i][j]) for j, idx in enumerate(indices[i])
    }
    for i in range(len(query_ids))
}

# %%
# Define evaluation metrics
metrics = {
    "map": "Mean Average Precision",
    "ndcg_cut_10": "NDCG@10",
    "ndcg_cut_20": "NDCG@20",
    "P_5": "Precision@5",
    "P_10": "Precision@10",
    "P_20": "Precision@20",
    "P_100": "Precision@100",
    "recall_100": "Recall@100",
    "recall_1000": "Recall@1000",
    "recip_rank": "Reciprocal Rank",
    "iprec_at_recall_0.00": "Interpolated Precision at 0.00 Recall",
    "iprec_at_recall_0.10": "Interpolated Precision at 0.10 Recall",
    "iprec_at_recall_0.20": "Interpolated Precision at 0.20 Recall",
    "iprec_at_recall_0.30": "Interpolated Precision at 0.30 Recall",
    "iprec_at_recall_0.40": "Interpolated Precision at 0.40 Recall",
    "iprec_at_recall_0.50": "Interpolated Precision at 0.50 Recall",
    "iprec_at_recall_0.60": "Interpolated Precision at 0.60 Recall",
    "iprec_at_recall_0.70": "Interpolated Precision at 0.70 Recall",
    "iprec_at_recall_0.80": "Interpolated Precision at 0.80 Recall",
    "iprec_at_recall_0.90": "Interpolated Precision at 0.90 Recall",
    "iprec_at_recall_1.00": "Interpolated Precision at 1.00 Recall",
    "Rprec": "R-Precision",
    "bpref": "Binary Preference",
}

# Initialize evaluator
evaluator = pytrec_eval.RelevanceEvaluator(qrels, metrics.keys())

# Compute metrics
results = evaluator.evaluate(run)

mean_metrics = {}

for metric in results[next(iter(results))].keys():  # Get metrics from the first query
    mean_metrics[metric] = sum(
        query_metrics[metric] for query_metrics in results.values()
    ) / len(results)

for metric, value in mean_metrics.items():
    print(f"{metric}: {value:.4f}")
# Out:
# map: 0.1116
# Rprec: 0.1434
# bpref: 0.4945
# recip_rank: 0.4319
# iprec_at_recall_0.00: 0.4543
# iprec_at_recall_0.10: 0.2986
# iprec_at_recall_0.20: 0.2205
# iprec_at_recall_0.30: 0.1582
# iprec_at_recall_0.40: 0.1110
# iprec_at_recall_0.50: 0.0764
# iprec_at_recall_0.60: 0.0357
# iprec_at_recall_0.70: 0.0271
# iprec_at_recall_0.80: 0.0203
# iprec_at_recall_0.90: 0.0141
# iprec_at_recall_1.00: 0.0133
# P_5: 0.2224
# P_10: 0.1867
# P_20: 0.1458
# P_100: 0.0620
# recall_100: 0.2698
# recall_1000: 0.4945
# ndcg_cut_10: 0.2413
# ndcg_cut_20: 0.2260

# %%
# Display results
for query_id, query_metrics in results.items():
    print(f"Query ID: {query_id}")
    for metric, value in query_metrics.items():
        print(f"  {metrics[metric]}: {value:.4f}")
# Out:
# Query ID: 301
#   Mean Average Precision: 0.0524
#   Precision@10: 0.3000
#   Recall@100: 0.1111
#   Recall@1000: 0.3056
#   NDCG@10: 0.3597
#   NDCG@20: 0.2321
# Query ID: 303
#   Mean Average Precision: 0.1500
#   Precision@10: 0.2000
#   Recall@100: 0.6667
#   Recall@1000: 0.8333
#   NDCG@10: 0.2468
#   NDCG@20: 0.3242
# Query ID: 304
#   Mean Average Precision: 0.1051
#   Precision@10: 0.1000
#   Recall@100: 0.2889
#   Recall@1000: 0.6222
#   NDCG@10: 0.2201
#   NDCG@20: 0.2897
# Query ID: 305
#   Mean Average Precision: 0.0128
#   Precision@10: 0.0000
#   Recall@100: 0.1667
#   Recall@1000: 0.1667
#   NDCG@10: 0.0000
#   NDCG@20: 0.0795
# Query ID: 306
#   Mean Average Precision: 0.1235
#   Precision@10: 0.7000
#   Recall@100: 0.1544
#   Recall@1000: 0.4926
#   NDCG@10: 0.7097
#   NDCG@20: 0.5285
# Query ID: 307
#   Mean Average Precision: 0.0677
#   Precision@10: 0.3000
#   Recall@100: 0.1481
#   Recall@1000: 0.4938
#   NDCG@10: 0.3070
#   NDCG@20: 0.2658
# Query ID: 308
#   Mean Average Precision: 0.0526
#   Precision@10: 0.1000
#   Recall@100: 0.5000
#   Recall@1000: 1.0000
#   NDCG@10: 0.1772
#   NDCG@20: 0.1772
# Query ID: 310
#   Mean Average Precision: 0.2405
#   Precision@10: 0.3000
#   Recall@100: 0.4286
#   Recall@1000: 0.5714
#   NDCG@10: 0.4555
#   NDCG@20: 0.4555
# Query ID: 311
#   Mean Average Precision: 0.0104
#   Precision@10: 0.1000
#   Recall@100: 0.0143
#   Recall@1000: 0.1143
#   NDCG@10: 0.2201
#   NDCG@20: 0.1817
# Query ID: 312
#   Mean Average Precision: 0.0000
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.0000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 313
#   Mean Average Precision: 0.0753
#   Precision@10: 0.3000
#   Recall@100: 0.1818
#   Recall@1000: 0.3182
#   NDCG@10: 0.2906
#   NDCG@20: 0.2259
# Query ID: 314
#   Mean Average Precision: 0.0291
#   Precision@10: 0.1000
#   Recall@100: 0.0952
#   Recall@1000: 0.2857
#   NDCG@10: 0.1389
#   NDCG@20: 0.0896
# Query ID: 315
#   Mean Average Precision: 0.0000
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.0000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 316
#   Mean Average Precision: 0.0000
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.0000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 317
#   Mean Average Precision: 0.0030
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 1.0000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 318
#   Mean Average Precision: 0.0058
#   Precision@10: 0.0000
#   Recall@100: 0.0889
#   Recall@1000: 0.1556
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 319
#   Mean Average Precision: 0.0072
#   Precision@10: 0.0000
#   Recall@100: 0.0400
#   Recall@1000: 0.2800
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 320
#   Mean Average Precision: 0.1262
#   Precision@10: 0.1000
#   Recall@100: 1.0000
#   Recall@1000: 1.0000
#   NDCG@10: 0.1510
#   NDCG@20: 0.1510
# Query ID: 321
#   Mean Average Precision: 0.0747
#   Precision@10: 0.5000
#   Recall@100: 0.1415
#   Recall@1000: 0.2830
#   NDCG@10: 0.5959
#   NDCG@20: 0.4882
# Query ID: 322
#   Mean Average Precision: 0.1137
#   Precision@10: 0.1000
#   Recall@100: 0.1111
#   Recall@1000: 0.3333
#   NDCG@10: 0.2350
#   NDCG@20: 0.2350
# Query ID: 323
#   Mean Average Precision: 0.0003
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.0333
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 324
#   Mean Average Precision: 0.4523
#   Precision@10: 1.0000
#   Recall@100: 0.4731
#   Recall@1000: 0.7312
#   NDCG@10: 1.0000
#   NDCG@20: 1.0000
# Query ID: 325
#   Mean Average Precision: 0.0053
#   Precision@10: 0.0000
#   Recall@100: 0.2000
#   Recall@1000: 0.6000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 326
#   Mean Average Precision: 0.2195
#   Precision@10: 0.5000
#   Recall@100: 0.4444
#   Recall@1000: 0.8222
#   NDCG@10: 0.4131
#   NDCG@20: 0.4406
# Query ID: 327
#   Mean Average Precision: 0.1458
#   Precision@10: 0.1000
#   Recall@100: 0.5000
#   Recall@1000: 0.5000
#   NDCG@10: 0.2463
#   NDCG@20: 0.2463
# Query ID: 328
#   Mean Average Precision: 0.3333
#   Precision@10: 0.2000
#   Recall@100: 0.5000
#   Recall@1000: 0.5000
#   NDCG@10: 0.5294
#   NDCG@20: 0.5294
# Query ID: 329
#   Mean Average Precision: 0.2556
#   Precision@10: 0.5000
#   Recall@100: 0.5000
#   Recall@1000: 0.7727
#   NDCG@10: 0.5479
#   NDCG@20: 0.4547
# Query ID: 330
#   Mean Average Precision: 0.0519
#   Precision@10: 0.2000
#   Recall@100: 0.3077
#   Recall@1000: 0.6923
#   NDCG@10: 0.1396
#   NDCG@20: 0.1632
# Query ID: 331
#   Mean Average Precision: 0.1702
#   Precision@10: 0.8000
#   Recall@100: 0.1902
#   Recall@1000: 0.4891
#   NDCG@10: 0.8116
#   NDCG@20: 0.7052
# Query ID: 332
#   Mean Average Precision: 0.0183
#   Precision@10: 0.1000
#   Recall@100: 0.1333
#   Recall@1000: 0.2000
#   NDCG@10: 0.0851
#   NDCG@20: 0.0660
# Query ID: 333
#   Mean Average Precision: 0.2683
#   Precision@10: 0.3000
#   Recall@100: 0.6316
#   Recall@1000: 0.9474
#   NDCG@10: 0.4690
#   NDCG@20: 0.3838
# Query ID: 334
#   Mean Average Precision: 0.0015
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.3333
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 335
#   Mean Average Precision: 0.5061
#   Precision@10: 0.1000
#   Recall@100: 0.5000
#   Recall@1000: 1.0000
#   NDCG@10: 0.6131
#   NDCG@20: 0.6131
# Query ID: 337
#   Mean Average Precision: 0.0048
#   Precision@10: 0.0000
#   Recall@100: 0.0769
#   Recall@1000: 0.2308
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 338
#   Mean Average Precision: 0.7500
#   Precision@10: 0.2000
#   Recall@100: 1.0000
#   Recall@1000: 1.0000
#   NDCG@10: 0.8772
#   NDCG@20: 0.8772
# Query ID: 339
#   Mean Average Precision: 0.3429
#   Precision@10: 0.3000
#   Recall@100: 0.8333
#   Recall@1000: 1.0000
#   NDCG@10: 0.4593
#   NDCG@20: 0.4593
# Query ID: 340
#   Mean Average Precision: 0.0557
#   Precision@10: 0.3000
#   Recall@100: 0.1600
#   Recall@1000: 0.2800
#   NDCG@10: 0.2934
#   NDCG@20: 0.1894
# Query ID: 341
#   Mean Average Precision: 0.1292
#   Precision@10: 0.2000
#   Recall@100: 0.5625
#   Recall@1000: 0.7500
#   NDCG@10: 0.2051
#   NDCG@20: 0.2366
# Query ID: 343
#   Mean Average Precision: 0.0798
#   Precision@10: 0.4000
#   Recall@100: 0.1429
#   Recall@1000: 0.4935
#   NDCG@10: 0.5175
#   NDCG@20: 0.3687
# Query ID: 344
#   Mean Average Precision: 0.0125
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 1.0000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 345
#   Mean Average Precision: 0.0347
#   Precision@10: 0.0000
#   Recall@100: 0.1765
#   Recall@1000: 0.5882
#   NDCG@10: 0.0000
#   NDCG@20: 0.0728
# Query ID: 346
#   Mean Average Precision: 0.0576
#   Precision@10: 0.3000
#   Recall@100: 0.1183
#   Recall@1000: 0.4516
#   NDCG@10: 0.3843
#   NDCG@20: 0.3188
# Query ID: 347
#   Mean Average Precision: 0.0639
#   Precision@10: 0.1000
#   Recall@100: 0.2400
#   Recall@1000: 0.5000
#   NDCG@10: 0.0734
#   NDCG@20: 0.1566
# Query ID: 348
#   Mean Average Precision: 0.0000
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.0000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 349
#   Mean Average Precision: 0.0017
#   Precision@10: 0.0000
#   Recall@100: 0.0769
#   Recall@1000: 0.2308
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 350
#   Mean Average Precision: 0.0072
#   Precision@10: 0.0000
#   Recall@100: 0.0541
#   Recall@1000: 0.3514
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 351
#   Mean Average Precision: 0.4069
#   Precision@10: 0.9000
#   Recall@100: 0.5000
#   Recall@1000: 0.7500
#   NDCG@10: 0.8900
#   NDCG@20: 0.6871
# Query ID: 352
#   Mean Average Precision: 0.0005
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.0377
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 353
#   Mean Average Precision: 0.1229
#   Precision@10: 0.5000
#   Recall@100: 0.2857
#   Recall@1000: 0.4694
#   NDCG@10: 0.5017
#   NDCG@20: 0.4342
# Query ID: 354
#   Mean Average Precision: 0.0079
#   Precision@10: 0.0000
#   Recall@100: 0.0563
#   Recall@1000: 0.2254
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 355
#   Mean Average Precision: 0.0007
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.5000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 356
#   Mean Average Precision: 0.0671
#   Precision@10: 0.1000
#   Recall@100: 0.0667
#   Recall@1000: 0.2000
#   NDCG@10: 0.2201
#   NDCG@20: 0.1706
# Query ID: 357
#   Mean Average Precision: 0.0928
#   Precision@10: 0.4000
#   Recall@100: 0.2500
#   Recall@1000: 0.5000
#   NDCG@10: 0.4531
#   NDCG@20: 0.2924
# Query ID: 359
#   Mean Average Precision: 0.0038
#   Precision@10: 0.0000
#   Recall@100: 0.0455
#   Recall@1000: 0.2273
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 360
#   Mean Average Precision: 0.1109
#   Precision@10: 0.2000
#   Recall@100: 0.3571
#   Recall@1000: 0.6429
#   NDCG@10: 0.2337
#   NDCG@20: 0.2337
# Query ID: 361
#   Mean Average Precision: 0.0000
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.0000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 362
#   Mean Average Precision: 0.0759
#   Precision@10: 0.1000
#   Recall@100: 0.6667
#   Recall@1000: 0.6667
#   NDCG@10: 0.1815
#   NDCG@20: 0.1815
# Query ID: 363
#   Mean Average Precision: 0.2592
#   Precision@10: 0.2000
#   Recall@100: 0.6667
#   Recall@1000: 1.0000
#   NDCG@10: 0.4197
#   NDCG@20: 0.4197
# Query ID: 364
#   Mean Average Precision: 0.2063
#   Precision@10: 0.2000
#   Recall@100: 0.6667
#   Recall@1000: 0.6667
#   NDCG@10: 0.3911
#   NDCG@20: 0.3911
# Query ID: 365
#   Mean Average Precision: 0.0788
#   Precision@10: 0.2000
#   Recall@100: 0.2727
#   Recall@1000: 0.2727
#   NDCG@10: 0.2048
#   NDCG@20: 0.1930
# Query ID: 366
#   Mean Average Precision: 0.0005
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.0526
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 367
#   Mean Average Precision: 0.0321
#   Precision@10: 0.1000
#   Recall@100: 0.0811
#   Recall@1000: 0.1622
#   NDCG@10: 0.2201
#   NDCG@20: 0.1420
# Query ID: 368
#   Mean Average Precision: 0.2227
#   Precision@10: 0.1000
#   Recall@100: 0.6000
#   Recall@1000: 0.8000
#   NDCG@10: 0.3392
#   NDCG@20: 0.3392
# Query ID: 369
#   Mean Average Precision: 0.1111
#   Precision@10: 0.1000
#   Recall@100: 1.0000
#   Recall@1000: 1.0000
#   NDCG@10: 0.3010
#   NDCG@20: 0.3010
# Query ID: 370
#   Mean Average Precision: 0.1627
#   Precision@10: 0.3000
#   Recall@100: 0.3200
#   Recall@1000: 0.7200
#   NDCG@10: 0.4153
#   NDCG@20: 0.3727
# Query ID: 371
#   Mean Average Precision: 0.0013
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.5000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 372
#   Mean Average Precision: 0.2769
#   Precision@10: 0.5000
#   Recall@100: 0.4667
#   Recall@1000: 0.7333
#   NDCG@10: 0.5670
#   NDCG@20: 0.4396
# Query ID: 373
#   Mean Average Precision: 0.0050
#   Precision@10: 0.0000
#   Recall@100: 0.0833
#   Recall@1000: 0.4167
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 374
#   Mean Average Precision: 0.0412
#   Precision@10: 0.2000
#   Recall@100: 0.1644
#   Recall@1000: 0.3288
#   NDCG@10: 0.1514
#   NDCG@20: 0.1332
# Query ID: 375
#   Mean Average Precision: 0.0115
#   Precision@10: 0.1000
#   Recall@100: 0.0769
#   Recall@1000: 0.3077
#   NDCG@10: 0.0663
#   NDCG@20: 0.0562
# Query ID: 376
#   Mean Average Precision: 0.0014
#   Precision@10: 0.0000
#   Recall@100: 0.0357
#   Recall@1000: 0.1786
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 377
#   Mean Average Precision: 0.0568
#   Precision@10: 0.2000
#   Recall@100: 0.2667
#   Recall@1000: 0.4667
#   NDCG@10: 0.1799
#   NDCG@20: 0.1395
# Query ID: 378
#   Mean Average Precision: 0.0014
#   Precision@10: 0.0000
#   Recall@100: 0.0114
#   Recall@1000: 0.1250
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 380
#   Mean Average Precision: 0.1000
#   Precision@10: 0.1000
#   Recall@100: 1.0000
#   Recall@1000: 1.0000
#   NDCG@10: 0.2891
#   NDCG@20: 0.2891
# Query ID: 381
#   Mean Average Precision: 0.0002
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.1429
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 382
#   Mean Average Precision: 0.0519
#   Precision@10: 0.1000
#   Recall@100: 0.3333
#   Recall@1000: 0.6667
#   NDCG@10: 0.1171
#   NDCG@20: 0.1171
# Query ID: 383
#   Mean Average Precision: 0.0396
#   Precision@10: 0.3000
#   Recall@100: 0.1163
#   Recall@1000: 0.3605
#   NDCG@10: 0.2614
#   NDCG@20: 0.2391
# Query ID: 384
#   Mean Average Precision: 0.1391
#   Precision@10: 0.1000
#   Recall@100: 0.5000
#   Recall@1000: 1.0000
#   NDCG@10: 0.2463
#   NDCG@20: 0.2463
# Query ID: 385
#   Mean Average Precision: 0.0879
#   Precision@10: 0.2000
#   Recall@100: 0.3235
#   Recall@1000: 0.7059
#   NDCG@10: 0.1635
#   NDCG@20: 0.1439
# Query ID: 386
#   Mean Average Precision: 0.0017
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.5000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 387
#   Mean Average Precision: 0.0255
#   Precision@10: 0.0000
#   Recall@100: 0.2308
#   Recall@1000: 0.6923
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 388
#   Mean Average Precision: 0.0422
#   Precision@10: 0.2000
#   Recall@100: 0.2667
#   Recall@1000: 0.2667
#   NDCG@10: 0.1357
#   NDCG@20: 0.1478
# Query ID: 389
#   Mean Average Precision: 0.0003
#   Precision@10: 0.0000
#   Recall@100: 0.0071
#   Recall@1000: 0.0357
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 390
#   Mean Average Precision: 0.0114
#   Precision@10: 0.0000
#   Recall@100: 0.0588
#   Recall@1000: 0.4706
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 391
#   Mean Average Precision: 0.0452
#   Precision@10: 0.3000
#   Recall@100: 0.0964
#   Recall@1000: 0.3373
#   NDCG@10: 0.2278
#   NDCG@20: 0.2870
# Query ID: 392
#   Mean Average Precision: 0.1362
#   Precision@10: 0.5000
#   Recall@100: 0.2600
#   Recall@1000: 0.3800
#   NDCG@10: 0.5580
#   NDCG@20: 0.5028
# Query ID: 393
#   Mean Average Precision: 0.0011
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.3333
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 394
#   Mean Average Precision: 0.0052
#   Precision@10: 0.0000
#   Recall@100: 0.2000
#   Recall@1000: 0.4000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 395
#   Mean Average Precision: 0.0835
#   Precision@10: 0.5000
#   Recall@100: 0.1720
#   Recall@1000: 0.4624
#   NDCG@10: 0.3827
#   NDCG@20: 0.3166
# Query ID: 396
#   Mean Average Precision: 0.4087
#   Precision@10: 0.4000
#   Recall@100: 0.5000
#   Recall@1000: 0.6000
#   NDCG@10: 0.5638
#   NDCG@20: 0.5638
# Query ID: 397
#   Mean Average Precision: 0.5454
#   Precision@10: 0.3000
#   Recall@100: 0.8750
#   Recall@1000: 0.8750
#   NDCG@10: 0.5215
#   NDCG@20: 0.7842
# Query ID: 398
#   Mean Average Precision: 0.0258
#   Precision@10: 0.1000
#   Recall@100: 0.1579
#   Recall@1000: 0.4737
#   NDCG@10: 0.0948
#   NDCG@20: 0.0632
# Query ID: 399
#   Mean Average Precision: 0.0037
#   Precision@10: 0.0000
#   Recall@100: 0.1000
#   Recall@1000: 0.3000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 400
#   Mean Average Precision: 0.1618
#   Precision@10: 0.3000
#   Recall@100: 0.3400
#   Recall@1000: 0.6200
#   NDCG@10: 0.4249
#   NDCG@20: 0.4549
# Query ID: 401
#   Mean Average Precision: 0.1945
#   Precision@10: 0.6000
#   Recall@100: 0.2208
#   Recall@1000: 0.6299
#   NDCG@10: 0.5337
#   NDCG@20: 0.5273
# Query ID: 402
#   Mean Average Precision: 0.1373
#   Precision@10: 0.2000
#   Recall@100: 0.3636
#   Recall@1000: 0.7273
#   NDCG@10: 0.2895
#   NDCG@20: 0.2616
# Query ID: 403
#   Mean Average Precision: 0.1684
#   Precision@10: 0.1000
#   Recall@100: 0.5000
#   Recall@1000: 1.0000
#   NDCG@10: 0.3066
#   NDCG@20: 0.3066
# Query ID: 404
#   Mean Average Precision: 0.0167
#   Precision@10: 0.0000
#   Recall@100: 0.0103
#   Recall@1000: 0.4742
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 405
#   Mean Average Precision: 0.1544
#   Precision@10: 0.2000
#   Recall@100: 0.2857
#   Recall@1000: 0.7143
#   NDCG@10: 0.3301
#   NDCG@20: 0.3119
# Query ID: 406
#   Mean Average Precision: 0.0074
#   Precision@10: 0.0000
#   Recall@100: 0.5000
#   Recall@1000: 1.0000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 407
#   Mean Average Precision: 0.0697
#   Precision@10: 0.2000
#   Recall@100: 0.3182
#   Recall@1000: 0.6818
#   NDCG@10: 0.1834
#   NDCG@20: 0.1184
# Query ID: 408
#   Mean Average Precision: 0.2091
#   Precision@10: 0.4000
#   Recall@100: 0.5405
#   Recall@1000: 0.6757
#   NDCG@10: 0.4885
#   NDCG@20: 0.3835
# Query ID: 409
#   Mean Average Precision: 0.1821
#   Precision@10: 0.5000
#   Recall@100: 0.2857
#   Recall@1000: 0.2857
#   NDCG@10: 0.5737
#   NDCG@20: 0.3702
# Query ID: 410
#   Mean Average Precision: 0.0802
#   Precision@10: 0.3000
#   Recall@100: 0.1905
#   Recall@1000: 0.4524
#   NDCG@10: 0.4153
#   NDCG@20: 0.3028
# Query ID: 411
#   Mean Average Precision: 0.2175
#   Precision@10: 0.3000
#   Recall@100: 0.5714
#   Recall@1000: 0.5714
#   NDCG@10: 0.3903
#   NDCG@20: 0.3903
# Query ID: 412
#   Mean Average Precision: 0.1113
#   Precision@10: 0.3000
#   Recall@100: 0.3810
#   Recall@1000: 0.6667
#   NDCG@10: 0.2999
#   NDCG@20: 0.2291
# Query ID: 413
#   Mean Average Precision: 0.0135
#   Precision@10: 0.0000
#   Recall@100: 0.0233
#   Recall@1000: 0.5116
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 414
#   Mean Average Precision: 0.2394
#   Precision@10: 0.5000
#   Recall@100: 0.6429
#   Recall@1000: 0.7857
#   NDCG@10: 0.3945
#   NDCG@20: 0.3662
# Query ID: 415
#   Mean Average Precision: 0.3464
#   Precision@10: 0.1000
#   Recall@100: 0.6667
#   Recall@1000: 0.6667
#   NDCG@10: 0.4693
#   NDCG@20: 0.4693
# Query ID: 416
#   Mean Average Precision: 0.1746
#   Precision@10: 0.4000
#   Recall@100: 0.3571
#   Recall@1000: 0.4286
#   NDCG@10: 0.4506
#   NDCG@20: 0.3648
# Query ID: 417
#   Mean Average Precision: 0.0174
#   Precision@10: 0.1000
#   Recall@100: 0.1316
#   Recall@1000: 0.2368
#   NDCG@10: 0.0851
#   NDCG@20: 0.0905
# Query ID: 418
#   Mean Average Precision: 0.0000
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.0000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 419
#   Mean Average Precision: 0.0692
#   Precision@10: 0.2000
#   Recall@100: 0.3750
#   Recall@1000: 0.6250
#   NDCG@10: 0.1493
#   NDCG@20: 0.2125
# Query ID: 420
#   Mean Average Precision: 0.2917
#   Precision@10: 0.2000
#   Recall@100: 0.5000
#   Recall@1000: 0.5000
#   NDCG@10: 0.4415
#   NDCG@20: 0.4415
# Query ID: 421
#   Mean Average Precision: 0.0310
#   Precision@10: 0.1000
#   Recall@100: 0.2258
#   Recall@1000: 0.3871
#   NDCG@10: 0.0636
#   NDCG@20: 0.0807
# Query ID: 422
#   Mean Average Precision: 0.3730
#   Precision@10: 0.8000
#   Recall@100: 0.5510
#   Recall@1000: 0.7143
#   NDCG@10: 0.8358
#   NDCG@20: 0.7560
# Query ID: 423
#   Mean Average Precision: 0.0972
#   Precision@10: 0.1000
#   Recall@100: 0.4286
#   Recall@1000: 0.8571
#   NDCG@10: 0.1734
#   NDCG@20: 0.1734
# Query ID: 424
#   Mean Average Precision: 0.0002
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.0455
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 425
#   Mean Average Precision: 0.1586
#   Precision@10: 0.3000
#   Recall@100: 0.3600
#   Recall@1000: 0.5600
#   NDCG@10: 0.3882
#   NDCG@20: 0.3641
# Query ID: 426
#   Mean Average Precision: 0.0303
#   Precision@10: 0.1000
#   Recall@100: 0.2222
#   Recall@1000: 0.3333
#   NDCG@10: 0.0909
#   NDCG@20: 0.0909
# Query ID: 427
#   Mean Average Precision: 0.1018
#   Precision@10: 0.2000
#   Recall@100: 0.4118
#   Recall@1000: 0.5882
#   NDCG@10: 0.2083
#   NDCG@20: 0.2290
# Query ID: 428
#   Mean Average Precision: 0.0750
#   Precision@10: 0.3000
#   Recall@100: 0.1600
#   Recall@1000: 0.3200
#   NDCG@10: 0.4374
#   NDCG@20: 0.3525
# Query ID: 429
#   Mean Average Precision: 0.0140
#   Precision@10: 0.0000
#   Recall@100: 0.5000
#   Recall@1000: 1.0000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 430
#   Mean Average Precision: 1.0000
#   Precision@10: 0.1000
#   Recall@100: 1.0000
#   Recall@1000: 1.0000
#   NDCG@10: 1.0000
#   NDCG@20: 1.0000
# Query ID: 431
#   Mean Average Precision: 0.0522
#   Precision@10: 0.1000
#   Recall@100: 0.2041
#   Recall@1000: 0.4694
#   NDCG@10: 0.0948
#   NDCG@20: 0.2009
# Query ID: 433
#   Mean Average Precision: 0.0000
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.0000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 434
#   Mean Average Precision: 0.2471
#   Precision@10: 0.8000
#   Recall@100: 0.3214
#   Recall@1000: 0.5833
#   NDCG@10: 0.6851
#   NDCG@20: 0.7231
# Query ID: 435
#   Mean Average Precision: 0.0363
#   Precision@10: 0.1000
#   Recall@100: 0.2800
#   Recall@1000: 0.4000
#   NDCG@10: 0.0694
#   NDCG@20: 0.0821
# Query ID: 436
#   Mean Average Precision: 0.4386
#   Precision@10: 0.5000
#   Recall@100: 0.6735
#   Recall@1000: 0.9592
#   NDCG@10: 0.5479
#   NDCG@20: 0.5688
# Query ID: 437
#   Mean Average Precision: 0.0039
#   Precision@10: 0.0000
#   Recall@100: 0.0149
#   Recall@1000: 0.1940
#   NDCG@10: 0.0000
#   NDCG@20: 0.0384
# Query ID: 438
#   Mean Average Precision: 0.0733
#   Precision@10: 0.1000
#   Recall@100: 0.2022
#   Recall@1000: 0.4831
#   NDCG@10: 0.0694
#   NDCG@20: 0.0812
# Query ID: 439
#   Mean Average Precision: 0.0176
#   Precision@10: 0.1000
#   Recall@100: 0.0282
#   Recall@1000: 0.1690
#   NDCG@10: 0.2201
#   NDCG@20: 0.1420
# Query ID: 440
#   Mean Average Precision: 0.0136
#   Precision@10: 0.0000
#   Recall@100: 0.1765
#   Recall@1000: 0.3529
#   NDCG@10: 0.0000
#   NDCG@20: 0.0378
# Query ID: 441
#   Mean Average Precision: 0.0000
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.0000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 442
#   Mean Average Precision: 0.0000
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 0.0000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 443
#   Mean Average Precision: 0.1202
#   Precision@10: 0.5000
#   Recall@100: 0.2319
#   Recall@1000: 0.5217
#   NDCG@10: 0.5740
#   NDCG@20: 0.4425
# Query ID: 444
#   Mean Average Precision: 0.3333
#   Precision@10: 0.1000
#   Recall@100: 0.3333
#   Recall@1000: 0.3333
#   NDCG@10: 0.4693
#   NDCG@20: 0.4693
# Query ID: 445
#   Mean Average Precision: 0.3951
#   Precision@10: 0.9000
#   Recall@100: 0.4746
#   Recall@1000: 0.5763
#   NDCG@10: 0.9364
#   NDCG@20: 0.8919
# Query ID: 446
#   Mean Average Precision: 0.0566
#   Precision@10: 0.1000
#   Recall@100: 0.1176
#   Recall@1000: 0.6471
#   NDCG@10: 0.1389
#   NDCG@20: 0.0896
# Query ID: 447
#   Mean Average Precision: 0.0033
#   Precision@10: 0.0000
#   Recall@100: 0.0000
#   Recall@1000: 1.0000
#   NDCG@10: 0.0000
#   NDCG@20: 0.0000
# Query ID: 448
#   Mean Average Precision: 0.0119
#   Precision@10: 0.0000
#   Recall@100: 0.1034
#   Recall@1000: 0.3793
#   NDCG@10: 0.0000
#   NDCG@20: 0.0348
# Query ID: 449
#   Mean Average Precision: 0.0070
#   Precision@10: 0.0000
#   Recall@100: 0.0682
#   Recall@1000: 0.2500
#   NDCG@10: 0.0000
#   NDCG@20: 0.0323
# Query ID: 450
#   Mean Average Precision: 0.0731
#   Precision@10: 0.2000
#   Recall@100: 0.1860
#   Recall@1000: 0.6279
#   NDCG@10: 0.2051
#   NDCG@20: 0.1993
